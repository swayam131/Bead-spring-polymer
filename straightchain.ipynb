# %%
import numpy as np
import math
import random

# system size
lxmin = 0.0
lxmax = 30.0
lymin = 0.0
lymax = 30.0
lzmin = 0.0
lzmax = 30.0



nmonomers = 1174
x=0.0
y=0.0
z=0.0

#for i in range(0,8):
   # x=x+1.12
    #y=y+1.12
    #z=z+1.12
    

    #print("%d %d %d %1.2f %1.2f %1.2f \n" % (i+1,1,1,x,y,z))
#for i in range(0,830):
 #   print("%d %d %d %d\n" % (i+1,1,i+1,i+2))
    
out = open('poly_5k.txt', "w")

out.write('# LAMMPS data file\n')
out.write('%d atoms\n' % nmonomers)
out.write('\n')
out.write('1 atom types\n')
out.write('1 bond types\n')
out.write('\n')
out.write('# System size\n')
out.write('%f %f xlo xhi\n' % (lxmin,lxmax))
out.write('%f %f ylo yhi\n' % (lymin,lymax))
out.write('%f %f zlo zhi\n' % (lzmin,lzmax))
out.write('\n')
out.write('Masses\n')
out.write('\n')
out.write('1 1\n')


out.write('\n')
out.write('Atoms\n')
out.write('\n')
for i in range(0,1174):
    x=0.0
    y=0.0
    z=z+1.0
    out.write("   %d   %d   %d   %1.2f   %1.2f   %1.2f\n" % (i+1,1,1,x,y,z))
out.write('\n')
out.write('# Bond topology\n')
out.write('Bonds\n')
out.write('\n')
for i in range(0,1174):
    out.write("   %d   %d   %d   %d\n" % (i+1,1,i+1,i+2))

out.close()
